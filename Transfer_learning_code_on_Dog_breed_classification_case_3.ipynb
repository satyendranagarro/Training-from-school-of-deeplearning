# %%
import os
import pandas as pd
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torch.utils.data import DataLoader, random_split

import torch.optim.lr_scheduler as scheduler
import torch.optim as optim
from datetime import datetime
import random


import torch.nn as nn
import torchvision.models as models

# %%
image_transforms = transforms.Compose([
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.Resize((128, 128)),               # Resize images to 128x128 pixels
    transforms.RandomHorizontalFlip(p=0.5),       # Randomly flip images horizontally with a probability of 0.5
    transforms.RandomVerticalFlip(p=0.5),         # Randomly flip images vertically with a probability of 0.5
    transforms.ToTensor()                         # Convert PIL Image to PyTorch Tensor
])

# %%
class AnimalDataset(Dataset):

    def __init__(self, rootpath, transform=None):

        self.rootpath = rootpath
        self.transform = transform
        self.allLabels = {}

        self.name1 = os.listdir(rootpath + 'cane/') 
        self.name2 = os.listdir(rootpath + 'cavallo/') 
        self.name3 = os.listdir(rootpath + 'elefante/') 
        self.name4 = os.listdir(rootpath + 'farfalla/') 
        self.name5 = os.listdir(rootpath + 'gallina/')
        self.name6 = os.listdir(rootpath + 'gatto/')
        self.name7 = os.listdir(rootpath + 'mucca/')
        self.name8 = os.listdir(rootpath + 'pecora/')
        self.name9 = os.listdir(rootpath + 'ragno/') 
        self.name10  = os.listdir(rootpath + 'scoiattolo/')


        for name in self.name1:
            self.allLabels[name] = 0
        for name in self.name2:
            self.allLabels[name] = 1
        for name in self.name3:
            self.allLabels[name] = 2
        for name in self.name4:
            self.allLabels[name] = 3
        for name in self.name5:
            self.allLabels[name] = 4
        for name in self.name6:
            self.allLabels[name] = 5
        for name in self.name7:
            self.allLabels[name] = 6
        for name in self.name8:
            self.allLabels[name] = 7
        for name in self.name9:
            self.allLabels[name] = 8
        for name in self.name10:
            self.allLabels[name] = 9

        self.allNames = list(self.allLabels.keys())
        random.shuffle(self.allNames)
        
        self.folders = ('cane/','cavallo/','elefante/', 'farfalla/', 'gallina/', 'gatto/','mucca/','pecora/', 'ragno/','scoiattolo/')

        self.count = 0

        self.allNames2 = []

    def __len__(self):
        return len(self.allNames)

    def __getitem__(self, index):        
        
        imageName = self.allNames[index]
        label = self.allLabels[imageName]        
        currentFolder = self.folders[label]
        img = Image.open(self.rootpath + currentFolder + imageName)

        if(self.transform):
            img = self.transform(img)

            
        return (img, label)

# %%
rootpath = 'data/archive/raw-img/'

import os 
os.listdir('data/archive/raw-img/')
os.listdir(rootpath + 'cane/')
# Out:
# ['OIP-7Kyjub53-QqanyWanuJpOwHaHx.jpeg',
#  'OIP-L3TRIOoPlmb3isOmx9DYDwHaEK.jpeg',
#  'OIP-bTKnRAJfpOhQhD4AC4ZjZAAAAA.jpeg',
#  'OIP-nj_6eSbDiI1jXD7cPD4i7wHaFr.jpeg',
#  'OIP-sH7u4NwO_gj427Z0cw3C5gHaEX.jpeg',
#  'OIP-KpXLr2QOZBB2ob4jLqQ_5AHaE8.jpeg',
#  'OIP-5hI4KOsaeyvSjy7_LiTJCgHaFm.jpeg',
#  'OIP-qgoh-WlYIKPSHlnkIp94BwHaHu.jpeg',
#  'OIP-Az2F3FRqzfmRmmUSgoxo7QHaJ4.jpeg',
#  'OIP-j9DWcaiwxPTVQAIKU9eSWQHaHa.jpeg',
#  'OIP-6furhdTd-uDJOqgJSnaBmQHaEL.jpeg',
#  'OIP-88kSxCY7XuMeAAGozExtbgAAAA.jpeg',
#  'OIP-spSfqC_Zu4BaETOdPG4S2AHaFj.jpeg',
#  'OIP-_spWp421K4axml9mvCNbyAHaHa.jpeg',
#  'OIP-l_gtZxNkJ5Br0yU-eFlMFQHaDe.jpeg',
#  'OIP-LeTDbxfES1mEHp-pnXOr1AHaFj.jpeg',
#  'OIP-DVrt4V1x262LY3GuGqKIQgHaHa.jpeg',
#  'OIP-iySGtITMEnT_KOivAkmrnwAAAA.jpeg',
#  'OIP-LuqOD4c2u9Rd_tkcyiM7OwHaEE.jpeg',
#  'OIP-A-Piz2jNj3iHWJIxzfDvgwHaFj.jpeg',
#  'OIP-YS5iZo21-pBOXrTToPlOGAHaE4.jpeg',
#  'OIP-qjbOla72CxtK1NuTBHYwuAHaJ4.jpeg',
#  'OIP-HvUZXtIbHeK0_N3arGPZIAHaDt.jpeg',
#  'OIP-AbiQdD8rKo8KO8bTz55rUwHaDK.jpeg',
#  'OIP-Wm5vZi59JPnF80f3W4Gb_gHaE6.jpeg',
#  'OIP-vQEtJsJ4F7TNP8XvtyN9EQHaDt.jpeg',
#  'OIP-z_9YifLhPW0QANVPHjl0KQHaIA.jpeg',
#  'OIP-NCvYclEJ3_1JoDHDtodMEQAAAA.jpeg',
#  'OIP-6aI8pgEPsGojn1UTh_cb7wHaE7.jpeg',
#  'OIP-zeC2W1-zIInkqY3PKd83xgHaJc.jpeg',
#  'OIP-5sCA6gLGlItmv8v3QyKiXQHaHK.jpeg',
#  'OIP-xukU1EIrpvrxA9pNTwaoWgHaE8.jpeg',
#  'OIP-yR0qOT2mrMxJ46dgjKSXcgHaHc.jpeg',
#  'OIP-9CJCX3DUKnsLyeTEhjP5wwHaFj.jpeg',
#  'OIP-sAxUsxsVOXMFF-6TVI1B7gHaG9.jpeg',
#  'OIP-R_PmQFKl33fHN34KqtnxiQHaFj.jpeg',
#  'OIP-wmbXmjVWEDsnrFxW3VJotAHaFj.jpeg',
#  'OIP-72ErGOUFB9bnO0-E_5hE9AHaE5.jpeg',
#  'OIP-8hQP-ZGHLofJeddNVwiYhgHaJ4.jpeg',
#  'OIP-LML_K5I-qshXDXP2pk8P3AHaE9.jpeg',
#  'OIP-RAQ9lF9S8uudo5sTKUkj9wHaED.jpeg',
#  'OIP-2NZHqlDoyEwzU0XAcZfIGwHaFi.jpeg',
#  'OIP-vzkzyLM_yC7-0OBgSUAfiQHaDt.jpeg',
#  'OIP-QhJgAfRwLZN_llvKNsWO7QHaI5.jpeg',
#  'OIP--LSF87v0ehcSg4hzc4Qy7QHaE8.jpeg',
#  'OIP-4Ml6a5G13AJIocl1zPH3mQHaFH.jpeg',
#  'OIP-1J2GTZlSQv0EqCc907fCzgHaEK.jpeg',
#  'OIP-9XjOkuk1VZcumj1-azpM5AHaKZ.jpeg',
#  'OIP-9XCHs9GEq7Lk2ZDGSdG16gHaF2.jpeg',
#  'OIP-fbVBaid9zoEclR0Up691SAHaKV.jpeg',
#  'OIP-dhRFxC1YeHAG_Moi0TCnBQHaJ4.jpeg',
#  'OIP-1LSP7JjBDGEXwEukPFh6HgHaEY.jpeg',
#  'OIP-aD_7tN6EN8qfm9-faP0nbwHaE6.jpeg',
#  'OIP-B2ozg9aItUXLFi6l03XtVQHaEK.jpeg',
#  'OIP-ddCnlSKliBrlH9-FotvUOwHaJ6.jpeg',
#  'OIP-9mYGxY0umGZi7EHqqwzVCwHaE7.jpeg',
#  'OIP-sKnfpKgUIzIjGoNBs_2BvwHaNK.jpeg',
#  'OIP-ZdOG7FaKX1_M9vzYKkRcCgHaFj.jpeg',
#  'OIP-RYHqGKgFI-twcPAs3TY3CgHaF8.jpeg',
#  'OIP-8aLnXf5oYBGtj09eGZQSDgHaFh.jpeg',
#  'OIP-lSl47THGpcPO5yJMcMv8hAAAAA.jpeg',
#  'OIP-pTvPYXBqScPEX65Ka-J79wHaF5.jpeg',
#  'OIP-8GA_XULyXXFHSjM2H0IZzwAAAA.jpeg',
#  'OIP-ekH1fPJXDqNCblUODwjEOQHaFj.jpeg',
#  'OIP-E9pww0f1I_bNgsxzoIkkGwHaHl.jpeg',
#  'OIP-HKh6xnI3b0DZdlOVPfrcMgHaD6.jpeg',
#  'OIP-DEhqfvk3r-UQ2oz9-_i0jQHaHT.jpeg',
#  'OIP-EJZk0GSdY5PG5FvxJpRjDAHaFA.jpeg',
#  'OIP-V5A9YtCR-OOXgrDjansSSQHaE8.jpeg',
#  'OIP-9NuAETbbVwtSWUmcM2Zp8wHaEq.jpeg',
#  'OIP-u3j2hWXL7Vj5ft8nzsdp7gHaFj.jpeg',
#  'OIP-x4zOVsLV23fNe1uSD80MbAHaE8.jpeg',
#  'OIP-SmaAvnzzJjaHP8Oibdsp9gHaHa.jpeg',
#  'OIP-B7i5z4xQM57Gl6_guP9xsAHaFj.jpeg',
#  'OIP-oH9D2UZBOCqqQQKh_BWrYgHaKI.jpeg',
#  'OIP-N8HCaeDE1I2pz4MJZo0dmAHaFj.jpeg',
#  'OIP-tu2yks_vMdiBoBPUlVQ-9wHaJP.jpeg',
#  'OIP-oQcXqt7mKqAUZgktr3sq8QHaFj.jpeg',
#  'OIP-_UAONiG9Xdvf5_3STkKzdwHaFK.jpeg',
#  'OIP-dZhCkfhc64P-j78iXIjsOAHaE6.jpeg',
#  'OIP-xN52sgPY4ZYj4O1dmKPPMgHaF6.jpeg',
#  'OIP-tMJKaHKq_YpNzhuclkq2gQHaFj.jpeg',
#  'OIP-ceWCq8jXmTyW_08RgdkoxQHaFj.jpeg',
#  'OIP-HoSVLtlXVcBfId14yd-jAwHaIM.jpeg',
#  'OIP-UICMfAu1Pg4WOKTXHC_uWgHaE8.jpeg',
#  'OIP-kVPQlsToy05P1SUVCrKpUwHaE6.jpeg',
#  'OIP-gL-w2iKHxz-jc-KOl-NMtgHaJ3.jpeg',
#  'OIP-T4hFO2jwE1w7SCybMCMTpwHaFP.jpeg',
#  'OIP-2SUSRcTE5Dn1v63ZKRBh2gAAAA.jpeg',
#  'OIP--S-Kzm1iB9TRHF7MpaJL3QHaEm.jpeg',
#  'OIP-xv34WPaluAOQCIeUqeJp4AHaFj.jpeg',
#  'OIP-NIEWtyqZBx-geNy5dc-voAHaHa.jpeg',
#  'OIP-TI01xgjHSUZlgluwX6m6tAHaE6.jpeg',
#  'OIP-PeDuCylUL_QzFgvxRlx3uAHaE8.jpeg',
#  'OIP-AHZm9N4WVxwIO4tZRT8npQHaH8.jpeg',
#  'OIP-2JCHRqKve3bRpIHN33ySPwAAAA.jpeg',
#  'OIP-RUrDoPOUrgW6A9x0dILo9QHaHl.jpeg',
#  'OIP-NECs68u019slRrDLZosHjwHaE6.jpeg',
#  'OIP-_JSASsAoNCi8Yi31z3u7SgHaJ4.jpeg',
#  'OIP-Zo0o5pRic21vud5Rhb-pHwHaJ7.jpeg',
#  'OIP--DQsiH-9LglDNlEvJpZQZQHaFw.jpeg',
#  'OIP-cOGgO_0P9g9R85BTZwt-DAHaEK.jpeg',
#  'OIP-ItBP3eU86qritSrRVWYnmAHaFj.jpeg',
#  'OIP-axwK4tfLfLrLvsvgMoz7WAAAAA.jpeg',
#  'OIP-X0rI4MBnS7L-Ou04MBa2KwHaHa.jpeg',
#  'OIP-37BmaMmElztxHt_9eNrLZgHaFk.jpeg',
#  'OIP-bDYjrCBWlijjUE1-aJNpNgHaGY.jpeg',
#  'OIP-m0fu8T_jJol7kvzVpeC0jwHaLG.jpeg',
#  'OIP-mxtpws70IxH7BgmAml7iHQHaJ4.jpeg',
#  'OIP-HwIa57dKpZO_zdLUciZJfgHaFj.jpeg',
#  'OIP-kVaW35yL4rfVvjA02AwVSgHaJ4.jpeg',
#  'OIP-6ILAr2FZ8ozVB1UBYR6grAHaFi.jpeg',
#  'OIP-MfK4OlKNslnARV5uTom2CgHaFb.jpeg',
#  'OIP-NpQdXTrDR_cgkGrDeuckHwHaHa.jpeg',
#  'OIP-K4N-G2lcyps3ZUQMSjNtaAHaFj.jpeg',
#  'OIP-O3a9d4EUQZ1z-ghAGvGbpwHaE6.jpeg',
#  'OIP-21b8qStyN5swsjUF2jHGlgHaJ4.jpeg',
#  'OIP-GaLpk_jvPKgJDI3PyL8vWwHaHa.jpeg',
#  'OIP-OsspG45X-GLzyEdYM2nkaAHaE7.jpeg',
#  'OIP-k_SVYF87ocjf_d0agq36awHaHg.jpeg',
#  'OIP-zdQUfAWn7xT6taYCv04wMgHaHb.jpeg',
#  'OIP-uc0Qk3SptgXWxqPCAgUlfAHaHD.jpeg',
#  'OIP-FVxaCxDHShAZw6UlLbjDoQHaE8.jpeg',
#  'OIP-RCTz7VE6uEpKe3bonE7eTgHaFj.jpeg',
#  'OIP-ysBAYy3a2FHEeEOtGMHzYQHaE4.jpeg',
#  'OIP-JUNGqJLv9K2EchIkMB2OHgHaDK.jpeg',
#  'OIP-l32J3C4BUsAaXaphBY-D7wHaLb.jpeg',
#  'OIP--t2FVkxQ6yBY4PR6jC0uLQHaLG.jpeg',
#  'OIP-DfFCEptPCtTn2_VZ4tODwQHaE6.jpeg',
#  'OIP-VJ3IitL15NX-TvZdputi4gHaEK.jpeg',
#  'OIP-F0lkmajYGyZ6EZ3sV9JswQHaEK.jpeg',
#  'OIP-v8ub_2AIS7O21ECsXyCFuwHaE7.jpeg',
#  'OIP-VtGtpLgsjfMfw4v3tdqHmwHaK3.jpeg',
#  'OIP-4fGNzxrgX_QW9tOGTIT9EwHaHa.jpeg',
#  'OIP-wu4G_-yVjip8s26RjSiobAHaF4.jpeg',
#  'OIP-YafEJ2K8cxLmuSNnnj0pYwAAAA.jpeg',
#  'OIP--565fkAJy3DoFs81C9uE1QHaEY.jpeg',
#  'OIP-02OsWT9t46zXPceBxMicNQAAAA.jpeg',
#  'OIP-LzZ-QfiQyvHYlHbmymqhgQHaHa.jpeg',
#  'OIP-I4C6RRhYt9Uf88oyL44pGQHaIG.jpeg',
#  'OIP-ohumI_Z7IajVJDQygOJWywHaJG.jpeg',
#  'OIP-aGY9RvED38vhd0IcxBbQBgHaNL.jpeg',
#  'OIP-w1SRBdCTmI-f7ywql-dWTwHaF7.jpeg',
#  'OIP-BHcRAmUPEz9pcd7sJTRJ8AHaE7.jpeg',
#  'OIP-KWW7fvXe6eBce-zBgZPrLwHaHa.jpeg',
#  'OIP-PTF4QKJ6VkHi4QqKJj3zEwHaFj.jpeg',
#  'OIP-VIXUIYfnTjemzHnwID9j-QHaIv.jpeg',
#  'OIP-mVFI0XpXBaevC2NIW849MQHaHM.jpeg',
#  'OIP-ZFuSOEL2yPGuCdTMpAjdRwHaJ4.jpeg',
#  'OIP-nLfpA_mqDXgX0byZGh9MxgHaHI.jpeg',
#  'OIP-nCte3HY4f9zw2B7VMScKJgAAAA.jpeg',
#  'OIP-mVuLuCxcHnPLhyKHYmnctQHaJ4.jpeg',
#  'OIP-NaJzHWxC75KRvrLRonNs6gHaFj.jpeg',
#  'OIP-g3IWohIiT6oV36_zc7l9KgHaG7.jpeg',
#  'OIP-UHKFKLPSpL4BCBaPFISN6wHaFi.jpeg',
#  'OIP-q96LTRnFDFgHQEGmGpMYKgHaFR.jpeg',
#  'OIP-nMo71cW_0ZZVjTxd71a4LgHaJP.jpeg',
#  'OIP-3dDSKrJy-mXAwQetL7O53wHaFq.jpeg',
#  'OIP-D45bVldK9UISTYXxfqOysAHaE8.jpeg',
#  'OIP-qqS2kpZVqakYbBQbAYDzbwHaI4.jpeg',
#  'OIP-pGcCzlmpQm6toLtN1uIgpQHaFd.jpeg',
#  'OIP-Jy3rQiS6SJwUjYIR26y3VQD2D9.jpeg',
#  'OIP-ValIQMkR0PA2CbQ5XO-MUwHaJt.jpeg',
#  'OIP-WZqiyBv97f5fkp5jXO9YuAHaE8.jpeg',
#  'OIP-1MV5ehdvqgv8jBq9-PU98gHaE8.jpeg',
#  'OIP-d5LgzPYkKx2o8TaLj2vzLQHaE7.jpeg',
#  'OIP-Chbai5ssqMEVxCBzZ2FFBwHaD5.jpeg',
#  'OIP-U0XBLSegU-gsaHhQvj-wpAHaE6.jpeg',
#  'OIP-BIL1SNCm_Xo9xgeUgEQxMAHaFf.jpeg',
#  'OIP-TMIdS_x9eCCLht9UxC18FgHaFj.jpeg',
#  'OIP-NvHvghu-xeP4NcQ5tKeegQHaFj.jpeg',
#  'OIP-E8Cf3nEEXi3cONxzy3ZP4QHaHK.jpeg',
#  'OIP-k1yOBwsBNbDxWda_mivTsQHaHa.jpeg',
#  'OIP-_nMPKqKDiVFRZNWBnnbRnQHaFY.jpeg',
#  'OIP-ljMiG4PbPeitFKNLEtEmwgHaJ4.jpeg',
#  'OIP-_t431jQrfdq6YUVpvifqpQEsEs.jpeg',
#  'OIP-dDH1dqYGL2Ra_oP-JNeiiAHaFj.jpeg',
#  'OIP-0qV19Xqejl0w8Pi5OWh0egHaE8.jpeg',
#  'OIP-BKYrTV6o94No8z1EFDmfDQHaGX.jpeg',
#  'OIP-y4RWFwEn-MOgDI-F8rxqyQHaFj.jpeg',
#  'OIP-ptbNerp2gqLz8VhhEtIOzgHaHa.jpeg',
#  'OIP-ARmx5aJnpBrDhv--cWfF-wHaE0.jpeg',
#  'OIP-iwKcwImdo5eFptZYfzWzGgHaFj.jpeg',
#  'OIP-tJ0BiAa0APOi3GNhtEYA_wHaE7.jpeg',
#  'OIP-k5OWzMIGuiXyUIWZETrgwgHaGq.jpeg',
#  'OIP-E40UTSm3zit11t4DyzzInQHaEK.jpeg',
#  'OIP-eouFfNViGx0kRDO8ShrJRgEgDY.jpeg',
#  'OIP-K-3A_fED_5wzTO9fxwMxkwHaFP.jpeg',
#  'OIP-vhiBhd2G_BF_ECi2ezktjwHaLH.jpeg',
#  'OIP-PccK4IsQWfgehq-hLOqx5AAAAA.jpeg',
#  'OIP--lnCqw9ajSJK5CxuFZo2TwHaFb.jpeg',
#  'OIP-cfu6ssuOkA9gjed398vNZQHaFp.jpeg',
#  'OIP-NgrA-bsx_PCjb_YrUy-zUQHaE7.jpeg',
#  'OIP-evI-0DnpLmX4JZGrEgCS_AHaI5.jpeg',
#  'OIP-VGDCEsynBjMj6Yj7VOAaugHaIP.jpeg',
#  'OIP-4DRbxSyHktw2YO6epweP6gHaGX.jpeg',
#  'OIP-_-AtcUnGMN6ht4EYKmgkXgHaE8.jpeg',
#  'OIP-wFS044XzyS-Zhsqs3dzfOgHaFj.jpeg',
#  'OIP-MtnPu8q8owg9PT8-BOmYLQHaE7.jpeg',
#  'OIP-7_b6BO01yoDYJIA1NQIkPQHaFf.jpeg',
#  'OIP-pKyn1rH3PLa3oZfniTVhtwHaFA.jpeg',
#  'OIP-5dvvsAcl19m0K2dJipvt2gHaFj.jpeg',
#  'OIP-dMYQaIjupfo-orGZy8sXcAHaE8.jpeg',
#  'OIP-Yj_dK3lLumjCC1BlCqhLegHaI0.jpeg',
#  'OIP-SxR4A_fGlA_bnUubtVmGNAHaEE.jpeg',
#  'OIP-uULufZ5H3gEl24BPyLNsLAHaFj.jpeg',
#  'OIP-_NdI2cCOqHqFqxgvXctVYAHaE8.jpeg',
#  'OIP-VU-qbCMGgaGljQY7HudSwwHaJ4.jpeg',
#  'OIP-CjlaN58PBrXvbPEhUo1YHgHaE7.jpeg',
#  'OIP-qOHYNrbfivj-sssVZpzbwgHaNJ.jpeg',
#  'OIP-4YJy1j3sKvavyc_C6GQMbwHaIb.jpeg',
#  'OIP-s8f2cUt-MXe8FwuE4QabKQHaJ3.jpeg',
#  'OIP-ZGX1oI93O0HvmEoGPcoZKAHaGh.jpeg',
#  'OIP-JT_L001SNstQL9K3GsjJqwHaJg.jpeg',
#  'OIP-Zaz8YSZFXDh7HG9deuHBUQHaIP.jpeg',
#  'OIP-RxviolrvIvf4E_YYwKBH5QHaHZ.jpeg',
#  'OIP-zlZydWefzVPcuE9dXXyVngHaEo.jpeg',
#  'OIP-ke3BTebIwKnugUVP-vWYWwHaE7.jpeg',
#  'OIP-RHF2c5ck4P50h81PyRF8kAHaE7.jpeg',
#  'OIP-xA7nhnFzcWBR9Bx2BgRVCgHaFX.jpeg',
#  'OIP-eUXiiYUf36jxm21KoUhEgAHaFY.jpeg',
#  'OIP-49TXkdHCI0smpsnvB2Z2rwHaGw.jpeg',
#  'OIP-CFXKtV6Sl1auDpiHV2qptQHaG2.jpeg',
#  'OIP-iL0Kd-NO2B24WlBtohTnNwHaFW.jpeg',
#  'OIP-nBG3QTmVwvGBG2EJH3AtHAHaIR.jpeg',
#  'OIP-gq56vGJCuclnpT0tkna6tAHaHa.jpeg',
#  'OIP-tZcgiYdtUaeaLMiUKf11QwAAAA.jpeg',
#  'OIP-8CYFYepucipN_i4VzUxJ1wAAAA.jpeg',
#  'OIP-Uq8NaVOoa1xz7dYQMg8lHgHaF_.jpeg',
#  'OIP-BCIQIPHk80xXqqqc7A0PTgHaE6.jpeg',
#  'OIP-kJxv6lqOMwf5eKBFL8aHvgHaLH.jpeg',
#  'OIP-BnI-pDSPZ7rv8sBxtc7AxAHaNK.jpeg',
#  'OIP-v49qLM0HLfwRZv7lWPGwUgHaGj.jpeg',
#  'OIP-GG4XxdZejFzULtebUe89QQHaGh.jpeg',
#  'OIP-ePBo6rX84vh8QAb78a4xTQHaFK.jpeg',
#  'OIP-xShRztGH7V0kY3k7ceAy-QHaHa.jpeg',
#  'OIP-k_qEfLRb7h-zw7X8uUPVZAHaFj.jpeg',
#  'OIP-iz8B657Gux8OMUTFP_5tHAHaFE.jpeg',
#  'OIP--hIXMAfOrmjSfDzjHHoZmwHaFj.jpeg',
#  'OIP-sYOrKBQU1wlnp-nCzpyDdQHaHa.jpeg',
#  'OIP-N9czyXFHOkKEHB9zfhp0jAHaHa.jpeg',
#  'OIP-94gtM2dl09f8XF1aT_e4EwHaE8.jpeg',
#  'OIP-d08qe9iBGKQwk8wPgAhB0QHaCj.jpeg',
#  'OIP-ZVzrRQlCFB1GIgmwC2y1GwHaFN.jpeg',
#  'OIP-WnhuXNQiH9YlRERyt_H1UgHaFj.jpeg',
#  'OIP-mJ0X6HDxW_LJTPA3XpTkXAHaFj.jpeg',
#  'OIP-OVJcthsOvyewOfXQ4pL9zgHaEK.jpeg',
#  'OIP-V1nxnCZPU10SRJggjmcivQHaF7.jpeg',
#  'OIP-yK6p7z0xmd5_3Z3EbX-niQHaJ4.jpeg',
#  'OIP-9pE3z5tKVDTpSLgpXF0qMgHaFn.jpeg',
#  'OIP-bSdQY9lx02G7V2W-xY0I5AHaJ4.jpeg',
#  'OIP-CEKtrx7b1G5_d5G5ksRGlAHaFj.jpeg',
#  'OIP-M45MimHbXIE_p96jClhpKQHaF6.jpeg',
#  'OIP-969vk79DHhyBA_tDdyJllAHaEz.jpeg',
#  'OIP-6V1hIWK8ix1Ge4YcelGtbQHaFv.jpeg',
#  'OIP-8wvsjpNdn5HGALPuhAuEHAHaJ4.jpeg',
#  'OIP-j0npBYYdXDecA1WqM9LFTQHaFj.jpeg',
#  'OIP-STzD_1hsSX-CJmPyv7mj8QHaHa.jpeg',
#  'OIP-RzxQYc78ePq9GkgiUyruVQHaDt.jpeg',
#  'OIP-4mbwSxNgGzbq6kuXNrxySQHaE7.jpeg',
#  'OIP-OkjoEgD4KhqG__wot88cdwHaEH.jpeg',
#  'OIP-sm7U5DOXvO_eTWgC8MUn3QHaFx.jpeg',
#  'OIP-CSKUhPKyWJk24mCG1pz-tgAAAA.jpeg',
#  'OIP-DZ-J-KaX7diO3-t5lCWWpAHaJJ.jpeg',
#  'OIP-lswuz12GTVfoUmEHvTzYrgHaEb.jpeg',
#  'OIP-s5hs8ujMS4K23Mioo51XtwHaF0.jpeg',
#  'OIP-5u3SQ9NJeJuIQSxKFyb4EgHaJ4.jpeg',
#  'OIP-QNlRpmSOIde_fMqJ5lAACAHaLZ.jpeg',
#  'OIP-jdYVqYmhif4QQCNtjh362AHaFj.jpeg',
#  'OIP-8s5kL5ETmSdt7XjoO-5J-gHaE7.jpeg',
#  'OIP-wzg3Nx2Cjpp72llQtkl3YQHaIp.jpeg',
#  'OIP-_ARj2MBgX4SCNmtoxg4J4wHaE7.jpeg',
#  'OIP-_MncrI_hg7qp1G39b6RdOgHaFj.jpeg',
#  'OIP-XAqy9B_BVqOTeliGJ8dmeAHaJi.jpeg',
#  'OIP-eBx7zkQmNG_HBXE5QPdP6QHaGx.jpeg',
#  'OIP-YPkzcLgvt5uVHwN4CaVldgEbDc.jpeg',
#  'OIP-8SQnAoduW-9f8NOUjfIA8wHaFj.jpeg',
#  'OIP-XEysXe5hzrxAQfMJieU8AgHaE7.jpeg',
#  'OIP-4pyv82oHmBIKOsYrIMHcNwHaFj.jpeg',
#  'OIP-thXB5Xdp2HZnFDRFXtsp4QHaJh.jpeg',
#  'OIP-JLGPZd5C0lAPr4uvliRDTAHaLL.jpeg',
#  'OIP-72wRcsZoxWQuf0mHYVRdigHaFj.jpeg',
#  'OIP-BOdoGlK49H1COl_EywqFDQEsDh.jpeg',
#  'OIP-AFdOPdr8MRp0JBeEWlZ3hAAAAA.jpeg',
#  'OIP-CRlgwzmOMHcNEJk5vxkI6QHaE7.jpeg',
#  'OIP-868muxIPaYP9j6mEMbig4QHaFL.jpeg',
#  'OIP-Y0O4gcL8TRLLlnfPkGTVOgHaMi.jpeg',
#  'OIP-tQo-uVkMFHb1Z0dN4b9S-AHaFj.jpeg',
#  'OIP-rznu5IgsANHg1GK4FkA0AgHaE7.jpeg',
#  'OIP-0mQIT4nlridLywx2VzDefwHaJn.jpeg',
#  'OIP-8olr2aNPR2bEx__c_3c21QHaE7.jpeg',
#  'OIP-h0ulX_FI6nBphahZK_w2GgHaJe.jpeg',
#  'OIP-TpmRCG2TNjevsaBGU8LWcwHaE7.jpeg',
#  'OIP-NoS1klMops2i5PKhfv1VnwHaE6.jpeg',
#  'OIP-FSh6Xu7BMEV_DrXmpAI_LAHaLE.jpeg',
#  'OIP-c7GQ5CUHx7uFPPpFWcKy1AHaFj.jpeg',
#  'OIP-1uFKDNprKv32Js9JO2KMCwHaFi.jpeg',
#  'OIP-gh3NP-1K1UvdGW16DvehTAHaE7.jpeg',
#  'OIP-c-gsCeZeEVMDDiz-ZfH1lQHaFj.jpeg',
#  'OIP-WfukF187NfSDkU_EU4ZczwHaEo.jpeg',
#  'OIP-y-uPVn9n28cEy2I9qTkG3AHaFj.jpeg',
#  'OIP-kI6G_FMDCwYqbvOFsLCK7AHaFk.jpeg',
#  'OIP-uOsSRoChXejAWwaK7mLn5QHaFj.jpeg',
#  'OIP-pXRyU259nBzWN2ajuFEvqAHaF_.jpeg',
#  'OIP-UHlLgSLi4zNAofBwQ6nnagHaJH.jpeg',
#  'OIP-EwWbP-y62Cvk-GNXtcqDoQAAAA.jpeg',
#  'OIP-xrSxcDBCYNeVw71Aq1vCJQHaFW.jpeg',
#  'OIP-aYy9nVll5BF2yOeQIq2y7AAAAA.jpeg',
#  'OIP-eSFeuZNXS5NrlLJs5lu6iAHaHa.jpeg',
#  'OIP-TTu2mPvTZm3IKS9nAYPWogHaFl.jpeg',
#  'OIP-LASkiOTkE7GgyBkjRz8gkQHaFj.jpeg',
#  'OIP-pHY8kUqE1GlWY5mk_Fbs7QHaHw.jpeg',
#  'OIP-Yw7jTscSHaubHA03cToMJQHaJ3.jpeg',
#  'OIP-ZL30TCUllw0zONKD_lIcvAAAAA.jpeg',
#  'OIP-8x8m3GXDlDdthPEIWmLdtAHaHa.jpeg',
#  'OIP-9vVxehPcBqrY9b9rf09dFQHaJQ.jpeg',
#  'OIP-s10117sPncX94C34n5iXbgHaGO.jpeg',
#  'OIP-Xt28_a2yRdZuYXRIGRVkzgHaIk.jpeg',
#  'OIP-QVyCbY6HJ0QizYrtqAxfKAHaHa.jpeg',
#  'OIP-6F_n8kJDFBlVE0Qch5hfqwHaHL.jpeg',
#  'OIP-lL81t0KAs_6jwbVkpndrvgAAAA.jpeg',
#  'OIP-1qbIy0bMYYBPj9Efylrj0AHaE8.jpeg',
#  'OIP-0cYdzGqi1lvZQkk0Hy0GGAHaIu.jpeg',
#  'OIP-THG9k0uy8aNnhNs5K-lrXgHaFz.jpeg',
#  'OIP--9pxEn5HUPsqA38ao3O7TgHaGV.jpeg',
#  'OIP-Ttk5VBelO982E8th6_aK0AHaFj.jpeg',
#  'OIP-JTZYVxvhcqixb39EqQmV_AHaE9.jpeg',
#  'OIP-AuPeEpvjEikZCzG9GNDHoQHaJ4.jpeg',
#  'OIP-BRcDquOCnBXtn2LRGlXVuAHaF7.jpeg',
#  'OIP-DLOqiyGcaqcbjoisNQwCGwHaFE.jpeg',
#  'OIP--jqyES48oZ9OFI3kFadEggHaEk.jpeg',
#  'OIP-onAsz1QXdIvBS_xq9H53TgHaFj.jpeg',
#  'OIP-GTPFdxx2Wom_J1yC4ujuzAHaFj.jpeg',
#  'OIP-pzQe8d5TpHkhyCL4yusY6wHaHU.jpeg',
#  'OIP-Mcyb8lurBBybbeJ8aArE3wHaFj.jpeg',
#  'OIP-utHdoJIYB7V-SwoJyE6WqAHaHa.jpeg',
#  'OIP-jDHcv34yrxxMq93B1BMEgwHaFj.jpeg',
#  'OIP-vd_MBhg7RIjQ2kxcvgyidgHaE8.jpeg',
#  'OIP-WioOCeH2RC2DoqjN5MNJOQHaEo.jpeg',
#  'OIP-Wvo3KlAsuiDH108QKeg5nwHaFj.jpeg',
#  'OIP-7CMsGs0YgimHW4clR8sLIAHaJ4.jpeg',
#  'OIP-a4uKU3y70nImErVaRhHh_wHaGv.jpeg',
#  'OIP-aOq2VWJcHaFQONlnuL9-_gAAAA.jpeg',
#  'OIP-GdOifgSEfknFSYFdULGUUwHaJz.jpeg',
#  'OIP-EOQMZ5IHnBjTt8yuCCVMugHaFR.jpeg',
#  'OIP-PsHsuD2_C20Iiix57MuieAHaFj.jpeg',
#  'OIP-TGCiqWv7MpWPqL1pZbVl7wAAAA.jpeg',
#  'OIP-eqt2uIhEnPuK0GQNKRkrAAHaF4.jpeg',
#  'OIP-FL14VwtnEzjiQwA8iPVs2QHaFk.jpeg',
#  'OIP-62MkWmccimUzkT5Sa4QQOgHaKX.jpeg',
#  'OIP-LBk61xKG1utMLyGyu0rnnQHaE7.jpeg',
#  'OIP-LLS-i8IORyQWzcyyXPrTAgHaE7.jpeg',
#  'OIP-WWIbHaOiVbivat84mtlruQHaFj.jpeg',
#  'OIP-23BtwlKZ4n2xmqktbnwBEQHaFj.jpeg',
#  'OIP-l8uU5raxuYT43ViucJyfuAHaK-.jpeg',
#  'OIP-_EFbuI6NO5_p1TclckVMHgHaMW.jpeg',
#  'OIP-4iQ-wix4e-Pv6La8fh8vagHaFj.jpeg',
#  'OIP-DBZiRX5sVQOIh_L0NSORMQHaJ6.jpeg',
#  'OIP-JsLBXqjj2sfKjrqFydJI4wHaLI.jpeg',
#  'OIP-M6wF2RE2xlCy3zRaIQmNmAHaFj.jpeg',
#  'OIP-cVpz9nBDWFZhKNFvAvwQTAHaKU.jpeg',
#  'OIP-QD9WCbok3HCcbS0XM0-EegHaEo.jpeg',
#  'OIP-v37BghNPYt1SxujMXiZQuwHaHa.jpeg',
#  'OIP-aoJfpx-FyMAIvh9Lb31kiQHaJ4.jpeg',
#  'OIP-fUdUcL6uWwAlv7dC-4o4JAHaE6.jpeg',
#  'OIP-J9K0oIOtu1dAr6xmkghysgHaEO.jpeg',
#  'OIP-Di5ZmDj5ImwVpJ0Cea1PMwHaFj.jpeg',
#  'OIP-1pWXyYosDRHiDD4jRKZA0AHaFj.jpeg',
#  'OIP-35ucx4XQ1xh6o72axi4zXQHaF7.jpeg',
#  'OIP-a19S6VH0ZmMsLy-aXs0BmgHaFj.jpeg',
#  'OIP-2sKsdEI6aaXSSWHJS-QxIAHaJ4.jpeg',
#  'OIP-fqALUl0Qfa4u4h6h-FGKTgHaHa.jpeg',
#  'OIP-B95cXok1TG-y5TP2HLSRwAHaE8.jpeg',
#  'OIP-xUmTJLHDhQzBDsZdqR9U6gHaFj.jpeg',
#  'OIP-8lgcY__IEwVybYkfnS0-EAHaFy.jpeg',
#  'OIP-ue-DlsitayfpFJtnfWEcIgHaHX.jpeg',
#  'OIP-tyPeZm1RSHdywCbxv2VtnwHaGh.jpeg',
#  'OIP-O8GJLNNKLwoZL2iRiwHbawHaFt.jpeg',
#  'OIP-OASA8rIFP0sWj4LpLypW-wHaHa.jpeg',
#  'OIP-nj0Ow1soDJTB1ouq0BAnQwHaE7.jpeg',
#  'OIP-5fdvDnLl7Rwb0o1l133W0gHaGS.jpeg',
#  'OIP-qCDp-QARQSEfs3XqmYMIQAHaFj.jpeg',
#  'OIP-UFC8SW22-zJ0So-_A0vm6wHaJn.jpeg',
#  'OIP-SjaaLC4SB_28PSPAWH8WMQHaE6.jpeg',
#  'OIP-wv9eIefbFqs4ONjRsU7h9AHaGa.jpeg',
#  'OIP-80ZMnDWor9jfFGWDYWpEGAHaLK.jpeg',
#  'OIP-OeJRQpXAI5cvKKWT45EeKQHaJ3.jpeg',
#  'OIP-w5jCZcWNfaTz8sM4c3xkHAHaFj.jpeg',
#  'OIP-DysO2PHysEtNx1mczntQFgHaFI.jpeg',
#  'OIP-yJhU-1x5zoyJ4RR5dLb-ZQHaIy.jpeg',
#  'OIP-7UY9wNfCKotCRdlenamYYQHaGI.jpeg',
#  'OIP-OPC2rKNOZfSJVxNFOQjoswHaE5.jpeg',
#  'OIP-NGsUfDyAruZ4AvMoF4TxBgHaHY.jpeg',
#  'OIP-LGAHNZns7AQN-UVY_SpCEQHaE7.jpeg',
#  'OIP-3Viz--nA1-To-iRrG70i7wAAAA.jpeg',
#  'OIP-YyeauP0zuVc7i91Up3M41AHaFj.jpeg',
#  'OIP-FhiLQncLGFmbk2K36W39dQHaJ4.jpeg',
#  'OIP-hJnDhoVLGtmDs-onA1YQ3AHaF7.jpeg',
#  'OIP-SLkg947pUIA4lUqwwAoRAgHaE7.jpeg',
#  'OIP-NZSZqqXWdkcR5zwJg41KmAHaJd.jpeg',
#  'OIP-0IJ5VSGF68QgQCiIKK-1kwHaE8.jpeg',
#  'OIP-PuBguEGZGtYkw7-NtPTuDAHaIj.jpeg',
#  'OIP-DoNysnbcKX_lyNxDirI3owHaJd.jpeg',
#  'OIP-OZrVvjNR6xHUIzwK70OMRwCoEs.jpeg',
#  'OIP-ET6gFUYEqtU08SYdq-5LRAHaI-.jpeg',
#  'OIP-DaxI-lJKJ9ORx70xAmT3kAHaFH.jpeg',
#  'OIP-_2Itmpob3Q0nbJKrHvtnfAHaJ3.jpeg',
#  'OIP-guH8Ki6dPAWX4I0dY9p0aAHaFj.jpeg',
#  'OIP-QuEL2vwXnDn0-AMA0sHwPwHaD0.jpeg',
#  'OIP-zRrQsa9zgLsrPKmaefCQjQHaJ4.jpeg',
#  'OIP-7zZ4zCUyt2021hPuhZ1jhAHaFj.jpeg',
#  'OIP-cqSA2Vq0adN_c5DWx7h7KQHaEZ.jpeg',
#  'OIP-2sIPje3EMq9bP0vV2OGfmwHaEG.jpeg',
#  'OIP-GFRKy9ZK5NjRvJCWK0bPMgHaJP.jpeg',
#  'OIP-HgR0iCYSKRVNtTu8jvsBYAHaIb.jpeg',
#  'OIP-hycA6E5_KxeNqITxY0OptQHaE-.jpeg',
#  'OIP-kPmI79wT15eWaZIBeHxoWAHaE9.jpeg',
#  'OIP-ODQuuuTKTsX7evGRvx23pgHaFj.jpeg',
#  'OIP-ciPwFhRC_OmUMQMXH3qoMAHaHa.jpeg',
#  'OIP-2rgJ1I0fK24EGc6R31cSeAHaFj.jpeg',
#  'OIP-C3t4Fwh6abGwYREjwUr8-AHaJ4.jpeg',
#  'OIP-CEo3sFzKoSMSFGQrKrdFpwHaGq.jpeg',
#  'OIP-7mWJzYwaSlQiyFYOsNzQJgHaE6.jpeg',
#  'OIP-KnQIxAg5gFSvo1T9IGIvKgEsDh.jpeg',
#  'OIP-1ATVAQaBK1DmRCx9hWYcRAHaJ4.jpeg',
#  'OIP-2n1-BxeFnu0JulW36p8yeAHaHn.jpeg',
#  'OIP-R5qXMIIhUZSzY0oq6LReZwEsC3.jpeg',
#  'OIP-oAfLxwxcFzxsV-JvuAXJUgHaFj.jpeg',
#  'OIP-nV8cegyzjZWZpQsuP8YUBQHaE8.jpeg',
#  'OIP-h8RJJ4M-ly7e-vjrziSdWAHaFj.jpeg',
#  'OIP-Ia2sHwfdN1xxBzxIV1TLewHaE7.jpeg',
#  'OIP-weLuJ4GCP21C_fGoklPaJQHaNK.jpeg',
#  'OIP-JSVgcdTC8Tu_tWm6fAovMgHaHa.jpeg',
#  'OIP-j6RmxHJHuRFkIgGzrCf-AAHaFs.jpeg',
#  'OIP-p0bdSCmvFFD2L5cbH7W_3gHaCy.jpeg',
#  'OIP-PyPcdcTr_9eK-aR3XDzRhAHaHa.jpeg',
#  'OIP-8-7hNE6Lv6TmH9y1dmWU1QHaFj.jpeg',
#  'OIP-IUIzkf676SNnlkVHh-tnyQHaFj.jpeg',
#  'OIP-A0kmXzxpPc_QFQDj56FxXQHaFj.jpeg',
#  'OIP-fZk0Ooq72HahX3M7yZjNswHaFj.jpeg',
#  'OIP-rXCrhc2LTpXBu4q0TQuH-QHaHa.jpeg',
#  'OIP-rwUMdnRXnQ0_0-oVXUt8tAHaE7.jpeg',
#  'OIP-TgA5YK459Wbt2AmSL-DXjAHaEK.jpeg',
#  'OIP-TqzwRyRqcawaLSBdGHVUngHaGP.jpeg',
#  'OIP-YxOpIdb7unl0qHd8e0jl5gHaF0.jpeg',
#  'OIP-LGgdIq_mrHL-YB7oy4fxVQHaE7.jpeg',
#  'OIP-hYmb7876zVaIhXcm6XnmqQHaH5.jpeg',
#  'OIP-gFuotffP_tXNl1j2kIumbgHaE7.jpeg',
#  'OIP-kexFQo0eRudh_3VyZzVN4gHaKI.jpeg',
#  'OIP-ELE9xLGUt6BgblG3pcteVgHaLA.jpeg',
#  'OIP-X9vg6Q0GfqgmJA_gyxj1SQHaFj.jpeg',
#  'OIP-6379WMCgTs6nDADROLO4vQHaEq.jpeg',
#  'OIP-nBKLIqtbCnxc2wvjl_o3qQDMEx.jpeg',
#  'OIP-Hw1hFG080jrdvfzzXFwe8gHaFW.jpeg',
#  'OIP-9_Uo_t2dEcP7pra6VM_04QHaJA.jpeg',
#  'OIP-1UiwAQdMbUHb6BflmmWKFAHaEK.jpeg',
#  'OIP-huehtpww2MuKBkd6sGr6RgHaG7.jpeg',
#  'OIP-7UPTRs5rNYI1iObpVIlt5AHaH6.jpeg',
#  'OIP-dA2MwQ3wOPUFbsqn9P6ZUwAAAA.jpeg',
#  'OIP-KTnWtlh_K4CpJNb4kI9SwgHaFQ.jpeg',
#  'OIP-sKEv-POgMkYjy_sp-Hi52wAAAA.jpeg',
#  'OIP-fW3N62tjhj8wTmOHH3JySgAAAA.jpeg',
#  'OIP-2XrAVXGsrgEe0r_qLn8efwHaE7.jpeg',
#  'OIP-lskN9LE2vNHf4p6SGQa1_QHaFj.jpeg',
#  'OIP-2OxWoqi3TX6T4Zw5HZX52wHaHa.jpeg',
#  'OIP-0M8AAbNON2zvyCEB2WEhLQHaE8.jpeg',
#  'OIP-QlXbiHipPL1UlrHCXIlf5QHaId.jpeg',
#  'OIP-lyN0Lr8TqiuyxRtdKwp3uQHaLH.jpeg',
#  'OIP-0Fr5OC5ePtaGGODisrMa0AHaJ3.jpeg',
#  'OIP-CzpQrfgnluhyPdgqoapc6gHaFj.jpeg',
#  'OIP-zLa3jby0f-U-eir6Fj5_8gHaD3.jpeg',
#  'OIP-hF7lGsZFGdfID7mvjfJWqQHaFj.jpeg',
#  'OIP-wnh3L_bkGhXEyNkFq6OIlQHaHo.jpeg',
#  'OIP-noZgtKctJ9YgugfwHACPngHaE7.jpeg',
#  'OIP-7XRBK5gFC5kfB26sHUNIGAHaGD.jpeg',
#  'OIP-ijlxGovsiJ0AhFn6spW6-AHaJg.jpeg',
#  'OIP-yP--Rnl7fF601Kc_UBOqoQHaGV.jpeg',
#  'OIP-Db8DLdMOt3xa4vd4Bbhw3QHaIV.jpeg',
#  'OIP-Ax1QcXuwpH3qFRhrmejwfQHaFj.jpeg',
#  'OIP-hoolVvulSNZCtsHdryf-TgHaFj.jpeg',
#  'OIP-BefcpB9vlRJ5mFgTbOFFoAHaFj.jpeg',
#  'OIP-x5XZIAL9w2n82iUDyb731gHaFj.jpeg',
#  'OIP-8XbiVDDgfCwG9LaPYebFgwHaEK.jpeg',
#  'OIP-bbDBhQxQ7lkCERMLfi2digHaEu.jpeg',
#  'OIP-rP-TIds3P3w_BmyBu5MYKgHaFj.jpeg',
#  'OIP-FjOe1BNYJQ753GUMJtUh2AHaE1.jpeg',
#  'OIP-Q_nYLATNwTEsRkMnu0trNgHaHN.jpeg',
#  'OIP-bD-H2URvaLo3lEhG2hWJ8wHaJ4.jpeg',
#  'OIP-woAVfOVc3q0w34gisV_o4gHaLK.jpeg',
#  'OIP-uuJ-qUI21gXIohXbv-Bd9wHaHa.jpeg',
#  'OIP-UjMtwLvlhdenV7TV2ZShcwHaHr.jpeg',
#  'OIP-oQ5ADyzMH0P3AOyTBZgNCgHaJQ.jpeg',
#  'OIP-jOyaRE-w_RZ9xc8qwbPGggAAAA.jpeg',
#  ...]

# %%
dataset = AnimalDataset(rootpath, transform = image_transforms)
print(len(dataset))
# Out:
# 25840

# %%
trainset, valset, testset = random_split(dataset, [15000, 5000, 5840])

batch_size = 64

trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
valloader = DataLoader(valset, batch_size=batch_size, shuffle=True)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=True)

# %%
num_train_batches = len(trainloader)
num_validation_batches = len(valloader)
num_test_batches = len(testloader)

# %%
dataset.count
# Out:
# 0

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device used for training is ",device)
# Out:
# Device used for training is  cpu

# %%
model = models.resnet18(weights='IMAGENET1K_V1')
model.fc = nn.Linear(512, 10)

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
for param in model.fc.parameters():
    param.requires_grad = True

# %%
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
frozen    = sum(p.numel() for p in model.parameters() if not p.requires_grad)
print(f"Trainable params : {trainable:,}")
print(f"Frozen params    : {frozen:,}")

# %%
# !pip install torch-summary
# Out:
# Collecting torch-summary
#   Downloading torch_summary-1.4.5-py3-none-any.whl.metadata (18 kB)
# Downloading torch_summary-1.4.5-py3-none-any.whl (16 kB)
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.5

# %%
from torchsummary import summary
summary(model, (3, 128, 128))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 64, 64]          9,408
# ├─BatchNorm2d: 1-2                       [-1, 64, 64, 64]          128
# ├─ReLU: 1-3                              [-1, 64, 64, 64]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 32, 32]          --
# ├─Sequential: 1-5                        [-1, 64, 32, 32]          --
# |    └─BasicBlock: 2-1                   [-1, 64, 32, 32]          --
# |    |    └─Conv2d: 3-1                  [-1, 64, 32, 32]          36,864
# |    |    └─BatchNorm2d: 3-2             [-1, 64, 32, 32]          128
# |    |    └─ReLU: 3-3                    [-1, 64, 32, 32]          --
# |    |    └─Conv2d: 3-4                  [-1, 64, 32, 32]          36,864
# |    |    └─BatchNorm2d: 3-5             [-1, 64, 32, 32]          128
# |    |    └─ReLU: 3-6                    [-1, 64, 32, 32]          --
# |    └─BasicBlock: 2-2                   [-1, 64, 32, 32]          --
# |    |    └─Conv2d: 3-7                  [-1, 64, 32, 32]          36,864
# |    |    └─BatchNorm2d: 3-8             [-1, 64, 32, 32]          128
# |    |    └─ReLU: 3-9                    [-1, 64, 32, 32]          --
# |    |    └─Conv2d: 3-10                 [-1, 64, 32, 32]          36,864
# |    |    └─BatchNorm2d: 3-11            [-1, 64, 32, 32]          128
# |    |    └─ReLU: 3-12                   [-1, 64, 32, 32]          --
# ├─Sequential: 1-6                        [-1, 128, 16, 16]         --
# |    └─BasicBlock: 2-3                   [-1, 128, 16, 16]         --
# |    |    └─Conv2d: 3-13                 [-1, 128, 16, 16]         73,728
# |    |    └─BatchNorm2d: 3-14            [-1, 128, 16, 16]         256
# |    |    └─ReLU: 3-15                   [-1, 128, 16, 16]         --
# |    |    └─Conv2d: 3-16                 [-1, 128, 16, 16]         147,456
# |    |    └─BatchNorm2d: 3-17            [-1, 128, 16, 16]         256
# |    |    └─Sequential: 3-18             [-1, 128, 16, 16]         8,448
# |    |    └─ReLU: 3-19                   [-1, 128, 16, 16]         --
# |    └─BasicBlock: 2-4                   [-1, 128, 16, 16]         --
# |    |    └─Conv2d: 3-20                 [-1, 128, 16, 16]         147,456
# |    |    └─BatchNorm2d: 3-21            [-1, 128, 16, 16]         256
# |    |    └─ReLU: 3-22                   [-1, 128, 16, 16]         --
# |    |    └─Conv2d: 3-23                 [-1, 128, 16, 16]         147,456
# |    |    └─BatchNorm2d: 3-24            [-1, 128, 16, 16]         256
# |    |    └─ReLU: 3-25                   [-1, 128, 16, 16]         --
# ├─Sequential: 1-7                        [-1, 256, 8, 8]           --
# |    └─BasicBlock: 2-5                   [-1, 256, 8, 8]           --
# |    |    └─Conv2d: 3-26                 [-1, 256, 8, 8]           294,912
# |    |    └─BatchNorm2d: 3-27            [-1, 256, 8, 8]           512
# |    |    └─ReLU: 3-28                   [-1, 256, 8, 8]           --
# |    |    └─Conv2d: 3-29                 [-1, 256, 8, 8]           589,824
# |    |    └─BatchNorm2d: 3-30            [-1, 256, 8, 8]           512
# |    |    └─Sequential: 3-31             [-1, 256, 8, 8]           33,280
# |    |    └─ReLU: 3-32                   [-1, 256, 8, 8]           --
# |    └─BasicBlock: 2-6                   [-1, 256, 8, 8]           --
# |    |    └─Conv2d: 3-33                 [-1, 256, 8, 8]           589,824
# |    |    └─BatchNorm2d: 3-34            [-1, 256, 8, 8]           512
# |    |    └─ReLU: 3-35                   [-1, 256, 8, 8]           --
# |    |    └─Conv2d: 3-36                 [-1, 256, 8, 8]           589,824
# |    |    └─BatchNorm2d: 3-37            [-1, 256, 8, 8]           512
# |    |    └─ReLU: 3-38                   [-1, 256, 8, 8]           --
# ├─Sequential: 1-8                        [-1, 512, 4, 4]           --
# |    └─BasicBlock: 2-7                   [-1, 512, 4, 4]           --
# |    |    └─Conv2d: 3-39                 [-1, 512, 4, 4]           1,179,648
# |    |    └─BatchNorm2d: 3-40            [-1, 512, 4, 4]           1,024
# |    |    └─ReLU: 3-41                   [-1, 512, 4, 4]           --
# |    |    └─Conv2d: 3-42                 [-1, 512, 4, 4]           2,359,296
# |    |    └─BatchNorm2d: 3-43            [-1, 512, 4, 4]           1,024
# |    |    └─Sequential: 3-44             [-1, 512, 4, 4]           132,096
# |    |    └─ReLU: 3-45                   [-1, 512, 4, 4]           --
# |    └─BasicBlock: 2-8                   [-1, 512, 4, 4]           --
# |    |    └─Conv2d: 3-46                 [-1, 512, 4, 4]           2,359,296
# |    |    └─BatchNorm2d: 3-47            [-1, 512, 4, 4]           1,024
# |    |    └─ReLU: 3-48                   [-1, 512, 4, 4]           --
# |    |    └─Conv2d: 3-49                 [-1, 512, 4, 4]           2,359,296
# |    |    └─BatchNorm2d: 3-50            [-1, 512, 4, 4]           1,024
# |    |    └─ReLU: 3-51                   [-1, 512, 4, 4]           --
# ├─AdaptiveAvgPool2d: 1-9                 [-1, 512, 1, 1]           --
# ├─Linear: 1-10                           [-1, 10]                  5,130
# ==========================================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# Total mult-adds (M): 614.69
# ==========================================================================================
# Input size (MB): 0.19
# Forward/backward pass size (MB): 12.38
# Params size (MB): 42.65
# Estimated Total Size (MB): 55.22
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Conv2d: 1-1                            [-1, 64, 64, 64]          9,408
# ├─BatchNorm2d: 1-2                       [-1, 64, 64, 64]          128
# ├─ReLU: 1-3                              [-1, 64, 64, 64]          --
# ├─MaxPool2d: 1-4                         [-1, 64, 32, 32]          --
# ├─Sequential: 1-5                        [-1, 64, 32, 32]          --
# |    └─BasicBlock: 2-1                   [-1, 64, 32, 32]          --
# |    |    └─Conv2d: 3-1                  [-1, 64, 32, 32]          36,864
# |    |    └─BatchNorm2d: 3-2             [-1, 64, 32, 32]          128
# |    |    └─ReLU: 3-3                    [-1, 64, 32, 32]          --
# |    |    └─Conv2d: 3-4                  [-1, 64, 32, 32]          36,864
# |    |    └─BatchNorm2d: 3-5             [-1, 64, 32, 32]          128
# |    |    └─ReLU: 3-6                    [-1, 64, 32, 32]          --
# |    └─BasicBlock: 2-2                   [-1, 64, 32, 32]          --
# |    |    └─Conv2d: 3-7                  [-1, 64, 32, 32]          36,864
# |    |    └─BatchNorm2d: 3-8             [-1, 64, 32, 32]          128
# |    |    └─ReLU: 3-9                    [-1, 64, 32, 32]          --
# |    |    └─Conv2d: 3-10                 [-1, 64, 32, 32]          36,864
# |    |    └─BatchNorm2d: 3-11            [-1, 64, 32, 32]          128
# |    |    └─ReLU: 3-12                   [-1, 64, 32, 32]          --
# ├─Sequential: 1-6                        [-1, 128, 16, 16]         --
# |    └─BasicBlock: 2-3                   [-1, 128, 16, 16]         --
# |    |    └─Conv2d: 3-13                 [-1, 128, 16, 16]         73,728
# |    |    └─BatchNorm2d: 3-14            [-1, 128, 16, 16]         256
# |    |    └─ReLU: 3-15                   [-1, 128, 16, 16]         --
# |    |    └─Conv2d: 3-16                 [-1, 128, 16, 16]         147,456
# |    |    └─BatchNorm2d: 3-17            [-1, 128, 16, 16]         256
# |    |    └─Sequential: 3-18             [-1, 128, 16, 16]         8,448
# |    |    └─ReLU: 3-19                   [-1, 128, 16, 16]         --
# |    └─BasicBlock: 2-4                   [-1, 128, 16, 16]         --
# |    |    └─Conv2d: 3-20                 [-1, 128, 16, 16]         147,456
# |    |    └─BatchNorm2d: 3-21            [-1, 128, 16, 16]         256
# |    |    └─ReLU: 3-22                   [-1, 128, 16, 16]         --
# |    |    └─Conv2d: 3-23                 [-1, 128, 16, 16]         147,456
# |    |    └─BatchNorm2d: 3-24            [-1, 128, 16, 16]         256
# |    |    └─ReLU: 3-25                   [-1, 128, 16, 16]         --
# ├─Sequential: 1-7                        [-1, 256, 8, 8]           --
# |    └─BasicBlock: 2-5                   [-1, 256, 8, 8]           --
# |    |    └─Conv2d: 3-26                 [-1, 256, 8, 8]           294,912
# |    |    └─BatchNorm2d: 3-27            [-1, 256, 8, 8]           512
# |    |    └─ReLU: 3-28                   [-1, 256, 8, 8]           --
# |    |    └─Conv2d: 3-29                 [-1, 256, 8, 8]           589,824
# |    |    └─BatchNorm2d: 3-30            [-1, 256, 8, 8]           512
# |    |    └─Sequential: 3-31             [-1, 256, 8, 8]           33,280
# |    |    └─ReLU: 3-32                   [-1, 256, 8, 8]           --
# |    └─BasicBlock: 2-6                   [-1, 256, 8, 8]           --
# |    |    └─Conv2d: 3-33                 [-1, 256, 8, 8]           589,824
# |    |    └─BatchNorm2d: 3-34            [-1, 256, 8, 8]           512
# |    |    └─ReLU: 3-35                   [-1, 256, 8, 8]           --
# |    |    └─Conv2d: 3-36                 [-1, 256, 8, 8]           589,824
# |    |    └─BatchNorm2d: 3-37            [-1, 256, 8, 8]           512
# |    |    └─ReLU: 3-38                   [-1, 256, 8, 8]           --
# ├─Sequential: 1-8                        [-1, 512, 4, 4]           --
# |    └─BasicBlock: 2-7                   [-1, 512, 4, 4]           --
# |    |    └─Conv2d: 3-39                 [-1, 512, 4, 4]           1,179,648
# |    |    └─BatchNorm2d: 3-40            [-1, 512, 4, 4]           1,024
# |    |    └─ReLU: 3-41                   [-1, 512, 4, 4]           --
# |    |    └─Conv2d: 3-42                 [-1, 512, 4, 4]           2,359,296
# |    |    └─BatchNorm2d: 3-43            [-1, 512, 4, 4]           1,024
# |    |    └─Sequential: 3-44             [-1, 512, 4, 4]           132,096
# |    |    └─ReLU: 3-45                   [-1, 512, 4, 4]           --
# |    └─BasicBlock: 2-8                   [-1, 512, 4, 4]           --
# |    |    └─Conv2d: 3-46                 [-1, 512, 4, 4]           2,359,296
# |    |    └─BatchNorm2d: 3-47            [-1, 512, 4, 4]           1,024
# |    |    └─ReLU: 3-48                   [-1, 512, 4, 4]           --
# |    |    └─Conv2d: 3-49                 [-1, 512, 4, 4]           2,359,296
# |    |    └─BatchNorm2d: 3-50            [-1, 512, 4, 4]           1,024
# |    |    └─ReLU: 3-51                   [-1, 512, 4, 4]           --
# ├─AdaptiveAvgPool2d: 1-9                 [-1, 512, 1, 1]           --
# ├─Linear: 1-10                           [-1, 10]                  5,130
# ==========================================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# Total mult-adds (M): 614.69
# ==========================================================================================
# Input size (MB): 0.19
# Forward/backward pass size (MB): 12.38
# Params size (MB): 42.65
# Estimated Total Size (MB): 55.22
# ==========================================================================================

# %%
# input1 = torch.rand(64, 3, 128,128)
# output = model(input1)
# print('final shape : ',output.shape)

# %%
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
lossFunction = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
decayLR = scheduler.StepLR(optimizer, step_size=1, gamma=0.9)
sig = nn.Sigmoid()

# %%
epochs = 10

losses=[]
vacc = []
vlosses = []

for j in range(epochs):
    
    epoch_start = datetime.now()
    
    add_loss = 0.0
    run_loss2 = 0
    
    for i,data in enumerate(trainloader):
        
        image, label = data            
        image = image.to(device)
        label = label.to(device)
    
        optimizer.zero_grad()
    
        output = model(image)

        # print("output shape : ", output.shape)
    
        loss = lossFunction(output, label)
        
        add_loss += loss.item()
        run_loss2 += loss.item()
        
        loss.backward()        
        optimizer.step()
        
        if(i % 100 == 99):
            print('Epoch %d, Batch %d, Loss %.8f ' % (j+1, i+1, add_loss / 100))
            add_loss = 0.0    
    
    losses.append(run_loss2 / num_train_batches)
    
    print('------------')
    print('Validating')
    print('------------')
    
    total = 0
    correct = 0
    vrun_loss=0
    
    model.eval()
    
    with torch.no_grad():
        
        add_vloss = 0.0
        
        for k, vdata in enumerate(valloader):
            
            val_image, val_label = vdata
            
            val_image = val_image.to(device)
            val_label = val_label.to(device)
            
            val_output = model(val_image)
            
            vloss = lossFunction(val_output, val_label)
            
            add_vloss += vloss.item()
            vrun_loss += vloss.item()
            
            if(k%100 == 99):
                print('Validation loss : ', add_vloss / 100)
                add_vloss = 0.0
            
            class_probability, class_prediction = torch.max(val_output, 1)
            
            total += len(val_label)
            
            correct += (class_prediction == val_label).sum().item()
            
        val_accuracy = correct / total
        
        vlosses.append(vrun_loss / num_validation_batches)
        vacc.append(val_accuracy)
        print('---------')
        print('Correct : ', correct)
        print('Total : ', total)
        print('Final Validation accuracy : ', val_accuracy)
        print('---------')
        epoch_end = datetime.now()
        print('Epoch time : ', (epoch_end - epoch_start).total_seconds())
        print('---------------------------------')
        
    model.train()
    decayLR.step()
    
    print('Previous Learning Rate : ', decayLR.get_last_lr())
    print('------------------------')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 31
#      28 add_loss += loss.item()
#      29 run_loss2 += loss.item()
# ---> 31 loss.backward()
#      32 optimizer.step()
#      34 if(i % 100 == 99):
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.style.use('seaborn-bright')

fig = plt.figure()

ax = plt.axes()

x_values = range(epochs)

losses2 = torch.tensor(losses).cpu()
vlosses2 = torch.tensor(vlosses).cpu()
vacc2 = torch.tensor(vacc).cpu()

ax.plot(x_values, losses2, color='blue',  linewidth=2, label='Training Loss' )
ax.plot(x_values, vlosses2, color='red',  linewidth=2, label='Validation Loss')
ax.plot(x_values, vacc2, color='green',  linewidth=2, label='Validation Accuracy')


plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss/Accuracy")
plt.tight_layout()

# %%
# softmax = nn.Softmax(dim=1)

correct = 0
total = 0


with torch.no_grad():
    
    for i, data in enumerate(testloader):
        
        test_image, test_label = data
       
        test_image = test_image.to(device)
        test_label = test_label.to(device)      
        
        test_output = model(test_image)
        
        class_probability, class_prediction = torch.max(test_output, 1)

        total += len(test_label)
        
        correct += (class_prediction == test_label).sum().item()
        
    final_test_accuracy = correct/total
    
    print('Correct : ', correct)
    print('Total : ', total)
    print('Test accuracy is ', final_test_accuracy)

# %%
# !pip install torchcam

# %%
from torchvision.io.image import read_image
from torchvision.transforms.functional import normalize, resize, to_pil_image
from torchcam.methods import GradCAM

# %%
img = read_image("data/archive/raw-img/elefante/OIP---LeldVL441fx5S66TGgVQAAAA.jpeg")
layerToFocus = "layer4"

cam = GradCAM(model, layerToFocus)

activations, class_idx = cam(img.unsqueeze(0).to(device))

print(activations.shape)
print(class_idx)

# %%
# Preprocess it for your chosen model
input_tensor = normalize(resize(img, (128, 128)) / 255., [0.5, 0.5, 0.5], [0.2, 0.2, 0.2])

input_tensor = input_tensor.to(device)
with GradCAM(model, target_layer = layerToFocus) as cam_extractor:
  # Preprocess your data and feed it to the model
  out = model(input_tensor.unsqueeze(0))
  # Retrieve the CAM by passing the class index and the model output
  activation_map = cam_extractor(out.squeeze(0).argmax().item(), out)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Preprocess it for your chosen model
# ----> 2 input_tensor = normalize(resize(img, (128, 128)) / 255., [0.5, 0.5, 0.5], [0.2, 0.2, 0.2])
#       4 input_tensor = input_tensor.to(device)
#       5 with GradCAM(model, target_layer = layerToFocus) as cam_extractor:
#       6   # Preprocess your data and feed it to the model
#
# NameError: name 'normalize' is not defined

# %%
import matplotlib.pyplot as plt
from torchcam.utils import overlay_mask

# Resize the CAM and overlay it
result = overlay_mask(to_pil_image(img), to_pil_image(activation_map[0].squeeze(0), mode='F'), alpha=0.5)
# Display it
plt.imshow(result); plt.axis('off'); plt.tight_layout(); plt.show()
